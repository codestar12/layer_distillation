# %%
import tensorflow as tf

# %%
model = tf.keras.models.load_model('../model.h5')
# Out:
# WARNING:tensorflow:No training configuration found in save file: the model was *not* compiled. Compile it manually.

# %%
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 32, 64)        1792
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_v2 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 32, 64)        0
# _________________________________________________________________
# sep_conv_0 (SeparableConv2D) (None, 32, 32, 64)        4736
# _________________________________________________________________
# replacement_batchnorm_0 (Bat (None, 32, 32, 64)        256
# _________________________________________________________________
# replacement_relu_0 (ReLU)    (None, 32, 32, 64)        0
# _________________________________________________________________
# sep_conv_1 (SeparableConv2D) (None, 32, 32, 64)        4736
# _________________________________________________________________
# replacement_batchnorm_1 (Bat (None, 32, 32, 64)        256
# _________________________________________________________________
# replacement_relu_1 (ReLU)    (None, 32, 32, 64)        0
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_v2_1 (Ba (None, 32, 32, 64)        256
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 64)        0
# _________________________________________________________________
# sep_conv_2 (SeparableConv2D) (None, 16, 16, 128)       8896
# _________________________________________________________________
# replacement_batchnorm_2 (Bat (None, 16, 16, 128)       512
# _________________________________________________________________
# replacement_relu_2 (ReLU)    (None, 16, 16, 128)       0
# _________________________________________________________________
# sep_conv_3 (SeparableConv2D) (None, 16, 16, 128)       17664
# _________________________________________________________________
# replacement_batchnorm_3 (Bat (None, 16, 16, 128)       512
# _________________________________________________________________
# replacement_relu_3 (ReLU)    (None, 16, 16, 128)       0
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_v2_2 (Ba (None, 16, 16, 128)       512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 128)       0
# _________________________________________________________________
# sep_conv_4 (SeparableConv2D) (None, 16, 16, 128)       17664
# _________________________________________________________________
# replacement_batchnorm_4 (Bat (None, 16, 16, 128)       512
# _________________________________________________________________
# replacement_relu_4 (ReLU)    (None, 16, 16, 128)       0
# _________________________________________________________________
# sep_conv_5 (SeparableConv2D) (None, 16, 16, 128)       17664
# _________________________________________________________________
# replacement_batchnorm_5 (Bat (None, 16, 16, 128)       512
# _________________________________________________________________
# replacement_relu_5 (ReLU)    (None, 16, 16, 128)       0
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_v2_3 (Ba (None, 16, 16, 128)       512
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# sep_conv_6 (SeparableConv2D) (None, 8, 8, 256)         34176
# _________________________________________________________________
# replacement_batchnorm_6 (Bat (None, 8, 8, 256)         1024
# _________________________________________________________________
# replacement_relu_6 (ReLU)    (None, 8, 8, 256)         0
# _________________________________________________________________
# sep_conv_7 (SeparableConv2D) (None, 8, 8, 256)         68096
# _________________________________________________________________
# replacement_batchnorm_7 (Bat (None, 8, 8, 256)         1024
# _________________________________________________________________
# replacement_relu_7 (ReLU)    (None, 8, 8, 256)         0
# _________________________________________________________________
# activation_4 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_v2_4 (Ba (None, 8, 8, 256)         1024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 256)         0
# _________________________________________________________________
# sep_conv_8 (SeparableConv2D) (None, 8, 8, 256)         68096
# _________________________________________________________________
# replacement_batchnorm_8 (Bat (None, 8, 8, 256)         1024
# _________________________________________________________________
# replacement_relu_8 (ReLU)    (None, 8, 8, 256)         0
# _________________________________________________________________
# sep_conv_9 (SeparableConv2D) (None, 8, 8, 256)         68096
# _________________________________________________________________
# replacement_batchnorm_9 (Bat (None, 8, 8, 256)         1024
# _________________________________________________________________
# replacement_relu_9 (ReLU)    (None, 8, 8, 256)         0
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_v2_5 (Ba (None, 8, 8, 256)         1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8, 8, 256)         0
# _________________________________________________________________
# sep_conv_10 (SeparableConv2D (None, 8, 8, 256)         68096
# _________________________________________________________________
# replacement_batchnorm_10 (Ba (None, 8, 8, 256)         1024
# _________________________________________________________________
# replacement_relu_10 (ReLU)   (None, 8, 8, 256)         0
# _________________________________________________________________
# sep_conv_11 (SeparableConv2D (None, 8, 8, 256)         68096
# _________________________________________________________________
# replacement_batchnorm_11 (Ba (None, 8, 8, 256)         1024
# _________________________________________________________________
# replacement_relu_11 (ReLU)   (None, 8, 8, 256)         0
# _________________________________________________________________
# activation_6 (Activation)    (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_v2_6 (Ba (None, 8, 8, 256)         1024
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# sep_conv_12 (SeparableConv2D (None, 4, 4, 512)         133888
# _________________________________________________________________
# replacement_batchnorm_12 (Ba (None, 4, 4, 512)         2048
# _________________________________________________________________
# replacement_relu_12 (ReLU)   (None, 4, 4, 512)         0
# _________________________________________________________________
# sep_conv_13 (SeparableConv2D (None, 4, 4, 512)         267264
# _________________________________________________________________
# replacement_batchnorm_13 (Ba (None, 4, 4, 512)         2048
# _________________________________________________________________
# replacement_relu_13 (ReLU)   (None, 4, 4, 512)         0
# _________________________________________________________________
# activation_7 (Activation)    (None, 4, 4, 512)         0
# _________________________________________________________________
# batch_normalization_v2_7 (Ba (None, 4, 4, 512)         2048
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 4, 512)         0
# _________________________________________________________________
# sep_conv_14 (SeparableConv2D (None, 4, 4, 512)         267264
# _________________________________________________________________
# replacement_batchnorm_14 (Ba (None, 4, 4, 512)         2048
# _________________________________________________________________
# replacement_relu_14 (ReLU)   (None, 4, 4, 512)         0
# _________________________________________________________________
# sep_conv_15 (SeparableConv2D (None, 4, 4, 512)         267264
# _________________________________________________________________
# replacement_batchnorm_15 (Ba (None, 4, 4, 512)         2048
# _________________________________________________________________
# replacement_relu_15 (ReLU)   (None, 4, 4, 512)         0
# _________________________________________________________________
# activation_8 (Activation)    (None, 4, 4, 512)         0
# _________________________________________________________________
# batch_normalization_v2_8 (Ba (None, 4, 4, 512)         2048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 4, 4, 512)         0
# _________________________________________________________________
# sep_conv_16 (SeparableConv2D (None, 4, 4, 512)         267264
# _________________________________________________________________
# replacement_batchnorm_16 (Ba (None, 4, 4, 512)         2048
# _________________________________________________________________
# replacement_relu_16 (ReLU)   (None, 4, 4, 512)         0
# _________________________________________________________________
# sep_conv_17 (SeparableConv2D (None, 4, 4, 512)         267264
# _________________________________________________________________
# replacement_batchnorm_17 (Ba (None, 4, 4, 512)         2048
# _________________________________________________________________
# replacement_relu_17 (ReLU)   (None, 4, 4, 512)         0
# _________________________________________________________________
# activation_9 (Activation)    (None, 4, 4, 512)         0
# _________________________________________________________________
# batch_normalization_v2_9 (Ba (None, 4, 4, 512)         2048
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# sep_conv_18 (SeparableConv2D (None, 2, 2, 512)         267264
# _________________________________________________________________
# replacement_batchnorm_18 (Ba (None, 2, 2, 512)         2048
# _________________________________________________________________
# replacement_relu_18 (ReLU)   (None, 2, 2, 512)         0
# _________________________________________________________________
# sep_conv_19 (SeparableConv2D (None, 2, 2, 512)         267264
# _________________________________________________________________
# replacement_batchnorm_19 (Ba (None, 2, 2, 512)         2048
# _________________________________________________________________
# replacement_relu_19 (ReLU)   (None, 2, 2, 512)         0
# _________________________________________________________________
# activation_10 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_v2_10 (B (None, 2, 2, 512)         2048
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# sep_conv_20 (SeparableConv2D (None, 2, 2, 512)         267264
# _________________________________________________________________
# replacement_batchnorm_20 (Ba (None, 2, 2, 512)         2048
# _________________________________________________________________
# replacement_relu_20 (ReLU)   (None, 2, 2, 512)         0
# _________________________________________________________________
# sep_conv_21 (SeparableConv2D (None, 2, 2, 512)         267264
# _________________________________________________________________
# replacement_batchnorm_21 (Ba (None, 2, 2, 512)         2048
# _________________________________________________________________
# replacement_relu_21 (ReLU)   (None, 2, 2, 512)         0
# _________________________________________________________________
# activation_11 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_v2_11 (B (None, 2, 2, 512)         2048
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# sep_conv_22 (SeparableConv2D (None, 2, 2, 512)         267264
# _________________________________________________________________
# replacement_batchnorm_22 (Ba (None, 2, 2, 512)         2048
# _________________________________________________________________
# replacement_relu_22 (ReLU)   (None, 2, 2, 512)         0
# _________________________________________________________________
# sep_conv_23 (SeparableConv2D (None, 2, 2, 512)         267264
# _________________________________________________________________
# replacement_batchnorm_23 (Ba (None, 2, 2, 512)         2048
# _________________________________________________________________
# replacement_relu_23 (ReLU)   (None, 2, 2, 512)         0
# _________________________________________________________________
# activation_12 (Activation)   (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_v2_12 (B (None, 2, 2, 512)         2048
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               262656
# _________________________________________________________________
# activation_13 (Activation)   (None, 512)               0
# _________________________________________________________________
# batch_normalization_v2_13 (B (None, 512)               2048
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_14 (Activation)   (None, 10)                0
# =================================================================
# Total params: 3,841,610
# Trainable params: 269,312
# Non-trainable params: 3,572,298
# _________________________________________________________________

# %%
import tensorflow as tf
import tensorflow.compat.v1.keras.backend as K


def get_flops(model):
    run_meta = tf.compat.v1.RunMetadata()
    opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()

    # We use the Keras session graph in the call to the profiler.
    flops = tf.compat.v1.profiler.profile(graph=K.get_session().graph,
                                run_meta=run_meta, cmd='op', options=opts)
    print(flops)
    return flops.total_float_ops  # Prints the "flops" of the model.


# .... Define your model here ....
print(get_flops(model))
# Out:
# name: "_TFProfRoot"
#
# 0

# %%
run_meta = tf.compat.v1.RunMetadata()
opts = tf.compat.v1.profiler.ProfileOptionBuilder.float_operation()

# We use the Keras session graph in the call to the profiler.
flops = tf.compat.v1.profiler.profile(graph=K.get_session().graph,
                            run_meta=run_meta, cmd='op', options=opts)
# Out:
# name: "_TFProfRoot"
# 0

# %%
import tensorflow as tf
import keras.backend as K
from keras.applications.mobilenet import MobileNet

run_meta = tf.RunMetadata()
with tf.Session(graph=tf.Graph()) as sess:
    K.set_session(sess)
    net = MobileNet(alpha=.75, input_tensor=tf.placeholder('float32', shape=(1,32,32,3)))

    opts = tf.profiler.ProfileOptionBuilder.float_operation()    
    flops = tf.profiler.profile(sess.graph, run_meta=run_meta, cmd='op', options=opts)

    opts = tf.profiler.ProfileOptionBuilder.trainable_variables_parameter()    
    params = tf.profiler.profile(sess.graph, run_meta=run_meta, cmd='op', options=opts)

    print("{:,} --- {:,}".format(flops.total_float_ops, params.total_parameters))
